# %%
print("testing")
# Out:
# testing

# %%
# %matplotlib inline

import matplotlib as mpl
mpl.rcParams['figure.dpi']= 150

# %run predict_faster_rcnn.py
# Out:
# /home/cnda/envs/t/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# model path is /home/tamirmal/workspace/faster_rcnn/original_impl/model_freeze_vgg_tau_dataset/model_frcnn.hdf5
# {0: 'Bus', 1: 'bg'}
# Loading weights from /home/tamirmal/workspace/faster_rcnn/original_impl/model_freeze_vgg_tau_dataset/model_frcnn.hdf5
# DSCF1137.JPG
# Elapsed time = 2.535249710083008
# [('Bus', 99.95372295379639)]
# DSCF1140.JPG
# Elapsed time = 0.6907682418823242
# [('Bus', 98.82981181144714)]
# DSCF1141.JPG
# Elapsed time = 0.6817924976348877
# [('Bus', 99.17508959770203)]
# DSCF1142.JPG
# Elapsed time = 0.6594085693359375
# [('Bus', 98.26291799545288), ('Bus', 94.05859112739563)]

# %%
print("done")
# Out:
# done
